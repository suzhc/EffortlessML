# %%
from EffortlessML.dataset import get_breast_cancer
from EffortlessML.exp import ExpML

# %%
data = get_breast_cancer()
exp = ExpML(X=data.get_x(), y=data.get_y(), model_name='mlp', n_folds=5)
# Out:
# ----------------
# Label: target, Model: mlp, Selector: all, Folds: 5
# Features count 30
# Fold: 0, acc is: 0.974,  precision is 0.986,  recall is 0.972, f1 is 0.979,  ROC is: 0.999
# Fold: 1, acc is: 0.956,  precision is 0.934,  recall is 1.0, f1 is 0.966,  ROC is: 0.997
# Fold: 2, acc is: 0.965,  precision is 0.947,  recall is 1.0, f1 is 0.973,  ROC is: 0.982
# Fold: 3, acc is: 0.991,  precision is 1.0,  recall is 0.986, f1 is 0.993,  ROC is: 1.0
# Fold: 4, acc is: 0.991,  precision is 0.986,  recall is 1.0, f1 is 0.993,  ROC is: 0.999

# %%
exp.plot_cm()

# %%
exp.plot_roc()
